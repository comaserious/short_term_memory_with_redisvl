# %%
data = """<!DOCTYPE html>\n\n<html lang=\"ko\">\n

<head>\n
    <meta charset=\"utf-8\" />\n
    <meta content=\"width=device-width, initial-scale=1.0\" name=\"viewport\" />\n
    <meta content=\"_csrf\" name=\"_csrf_parameter\">
    <meta content=\"X-CSRF-TOKEN\" name=\"_csrf_header\">
    <meta content=\"d4e8959f-0d9b-48f1-89d0-8559aafaae91\" name=\"_csrf\" />\n
    <meta content=\"ie=edge\" http-equiv=\"X-UA-Compatible\" />\n<title>국민신문고</title>\n
    <link href=\"/resource/css/paid/nep/pot/css.css?version=1.01\" rel=\"stylesheet\" type=\"text/css\" />\n
    <link href=\"/resource/js/paid/cmmn/mCustomScrollbar/jquery.mCustomScrollbar.css\" rel=\"stylesheet\" type=\"text/css\" />\n
    <link href=\"/resource/css/paid/cmmn/jAlert.css\" rel=\"stylesheet\" type=\"text/css\" />\n<script type=\"text/javascript\">
        \
        r\ n\ tvar contexts = \"\";\r\n\t\r\n\t\r\n\tvar exnMnTxt = \"jpg, jpeg, gif, png, bmp, txt, pdf, hwp, gul, docx, doc, zip, xls, xlsx, ppt, pptx, mp4, avi, wmv, asf, flv, mov, mkv, mpeg, mpg, 3gp, wmv, webm, ogm, asx, m2t, m2ts, mts, tif, tiff, wav, mp3, 3ga, m4a, amr, mp2, hwpx, odt, csv\";\r\n\tvar exnMnArr = [\"jpg\",\"jpeg\",\"gif\",\"png\",\"bmp\",\"txt\",\"pdf\",\"hwp\",\"gul\",\"docx\",\"doc\",\"zip\",\"xls\",\"xlsx\",\"ppt\",\"pptx\",\"mp4\",\"avi\",\"wmv\",\"asf\",\"flv\",\"mov\",\"mkv\",\"mpeg\",\"mpg\",\"3gp\",\"wmv\",\"webm\",\"ogm\",\"asx\",\"m2t\",\"m2ts\",\"mts\",\"tif\",\"tiff\",\"wav\",\"mp3\",\"3ga\",\"m4a\",\"amr\",\"mp2\",\"hwpx\",\"odt\",\"csv\"];\r\n\tvar JBOSS_NODE_NAME = 'euser34';\r\n
    </script>\n<script src=\"/resource/js/paid/cmmn/jquery-1.12.4.min.js\" type=\"text/javascript\"></script>\n<script src=\"/resource/js/paid/cmmn/jquery-ui.min.js\" type=\"text/javascript\"></script>\n<script src=\"/resource/js/paid/cmmn/jquery.cookie.js\" type=\"text/javascript\"></script>\n<script src=\"/resource/js/paid/cmmn/bootstrap.min.js\" type=\"text/javascript\"></script>\n<script src=\"/resource/js/paid/cmmn/loading.js\" type=\"text/javascript\"></script>\n<script src=\"/resource/js/paid/cmmn/sendAjaxReq.js\" type=\"text/javascript\"></script>\n<script src=\"/resource/js/paid/cmmn/jquery.form.js\" type=\"text/javascript\"></script>\n<script src=\"/resource/js/paid/cmmn/mCustomScrollbar/jquery.mCustomScrollbar.concat.min.js\" type=\"text/javascript\">
    </script>\n<script src=\"/resource/js/paid/cmmn/pgwslideshow/pgwslideshow.min.js\" type=\"text/javascript\">
    </script>\n<script src=\"/resource/js/paid/nep/pot/common.js\" type=\"text/javascript\"></script>\n<script src=\"/resource/js/paid/cmmn/common.js\" type=\"text/javascript\"></script>\n
    <!-- [if lt IE 9]>\r\n<script type=\"text/javascript\" src=\"/resource/js/paid/cmmn/html5shiv.min.js\"></script>\r\n<![endif]-->\n
    <script src=\"/resource/js/paid/cmmn/jquery.money.plus.js\" type=\"text/javascript\"></script>\n<script src=\"/resource/js/paid/cmmn/jquery.alphanumeric.js\" type=\"text/javascript\"></script>\n<script src=\"/resource/js/paid/cmmn/jquery.alerts.js\" type=\"text/javascript\"></script>\n<script src=\"/resource/js/paid/cmmn/validation.js\" type=\"text/javascript\"></script>\n<script src=\"/resource/js/paid/nep/cmmn/netfunnel/netfunnel.js?ver=1.0\" type=\"text/javascript\"></script>\n<script src=\"/resource/js/paid/nep/cmmn/netfunnel/nfnSkin.js?ver=1.0\" type=\"text/javascript\"></script>\n<script src=\"/resource/js/paid/cmmn/common.popup.js\" type=\"text/javascript\"></script>\n<script type=\"text/javascript\">
        \
        r\ n\ tvar acesMode = 'frm'; //프레임 접근 구분자\r\n\t$(function(){\r\n\t\tif (acesMode == 'frm') {\r\n\t\t\t$('#contentWrap').addClass('full');  //프레임일 경우 화면 레이아웃 Full\r\n\t\t}\r\n\r\n\t\t//$(document).attr('title', $(document).attr('title') + ' | ' + JBOSS_NODE_NAME);\r\n\t});\r\n
    </script>\n</meta>
    </meta>
</head>\n

<body>\n<div class=\"loading black\" style=\"position:fixed; width:100%; height:auto; min-height:100%; z-index:100; top:0; left:0; display:block; opacity:.6;\">\n<div style=\"width:100%; height:100%; top:50%; left:50%; position:absolute;\">
            \n<span style=\"display:table-cell; text-align:center; vertical-align:middle;\">\n<img alt=\"로딩중\" src=\"/resource/images/paid/cmmn/bg_progress.gif\" />\n</span>\n
        </div>\n</div>\n<div id=\"wrap\">\n
        <!-- 세션에 접근 시스템 구분자가 프레임이 아닐 경우(프레임 통합 메뉴로 접근시 세션에 접근 시스템 구분자를 추가)만 헤더와 푸터를 포함하도록 처리 -->\n<div id=\"containerAcc\"></div>\n<main id=\"container\">\n<section id=\"member\">\n<script type=\"text/javascript\">
                    \
                    r\ n\ r\ n\ t //20200408/프레임통합 노경용/프레임통합메뉴 관련 변수 추가 시작\r\n\tvar frm_frmMenuMngNo = 'WBF-1202-000044';  //프레임메뉴관리번호\r\n\tvar frm_prcsInstChcePsblYn = 'N';  //처리기관선택가능여부\r\n\tvar frm_thptInfofAgreYn = '';  //제3자정보제공동의추가여부(프레임 관리 옵션)\r\n\tvar frmDsgnType = '';  //프레임 디자인 타입\r\n\tvar frm_frmMenuClsfCd = '';  //메뉴분류코드\r\n\tvar frm_chrgDeptCd = '';  //부서코드\r\n\tvar frm_pttnDrctRcptYn = '';  //민원직접접수여부\r\n\tvar frm_rcptTySctnCd = '';  //접수유형(부서접수/중간분류접수)\r\n\tvar frm_clsfRpsnNm = '';  //신청분야\r\n\tfrm_clsfRpsnNm = frm_clsfRpsnNm.replace(\"&#x28;\", \"(\").replace(\"&#x29;\", \")\");  //신청분야 특수문자 \"(\", \")\" 치환\r\n\tvar frm_frmMngrCnt = '0';  // 메뉴처리 담당자수\r\n\tvar frm_sysCrtnMngrIdCnt = '0';\r\n\tvar frm_clsfAplcYn = 'N';\r\n\tvar thptInfofAgreListYn = '';  //제3자정보제공동의정보 조회 결과 여부\r\n\t//var frm_lognIndcYn = '';  //로그인표시여부\r\n\tvar requestUri = '/frm/bdgt/bdgtWstRqstInfo.npaid';  //프레임 requestURI\r\n\tvar returnUrl = '';  //returnUrl\r\n\tvar thirdInfoMode = '';  //제3자동의구분\r\n\t//20200408/프레임통합 노경용/프레임통합메뉴 관련 변수 추가 끝\r\n\r\n\tvar checkedYn = $('input:checkbox[name=\"thptInfofAgreYn\"]').is(\":checked\");\r\n\tvar thptInfofAgreYn =\"\";\r\n\tvar dplcSbrbPrvnStvl = \"\";\r\n\r\n\t$(function(){\r\n\t\treturnUrl = fn_getReturnUrl();\r\n\t\tif ($.chkEmptyVal(frm_frmMenuMngNo)) {  //세션에 프레임메뉴관리번호가 존재하면 프레임통합메뉴로 인증 후 접근한 것\r\n\t\t\t//$('#subTit').hide();  //헤더 숨김\r\n\t\t\tif(frm_clsfAplcYn == \"Y\"){\r\n\t\t\t\tif($.chkEmptyVal(frm_frmMenuClsfCd) && $.chkEmptyVal(frm_clsfRpsnNm)){\r\n\t\t\t\t\t$('#div_frmMenuClsfCd').css({\r\n\t\t\t\t\t\t'color':'#000'\r\n\t\t\t\t\t\t,\t'paddingTop':'30px'\r\n\t\t\t\t\t\t,\t'paddingLeft' : '20px'\r\n\t\t\t\t\t\t,\t'fontSize' : '18px'\r\n\t\t\t\t\t\t,\t'fontWeight' : 'bold'\r\n\t\t\t\t\t\t,\t'marginTop' : '30px'\r\n\t\t\t\t\t}).text(\"신청분야 : \" + frm_clsfRpsnNm);\r\n\t\t\t\t\t$('#div_frmMenuClsfCd').show();\r\n\t\t\t\t}\r\n\t\t\t}\r\n\r\n\t\t\t//프레임 디자인 타입 설정\r\n\t\t\tif ($.chkEmptyVal(frmDsgnType) && frmDsgnType != 'basic') {  //basic=blue\r\n\t\t\t\t$('#div_frmDsgnType').addClass(frmDsgnType);\r\n\t\t\t}\r\n\r\n\t\t\tif (frm_prcsInstChcePsblYn != 'Y') {\r\n\t\t\t\t$('#div_step2').hide();  //2 기관선택 탭 숨김\r\n\t\t\t\t$('#span_step3').text('2 신청완료');  //탭 숫자 변경\r\n\t\t\t}\r\n\r\n\t\t\tif (thirdInfoMode == '1' || thirdInfoMode == '5') {  //민원신청(메뉴분류 포함)\r\n\t\t\t\tif (frm_thptInfofAgreYn == 'Y' && thptInfofAgreListYn == 'Y') {  //제3자정보제공동의\r\n\t\t\t\t\t$('#div_thptInfofAgre').show();  //개인정보 제3자 이용동의 영역 보임\r\n\r\n// \t\t\t\t\tif (frm_thptInfofAgreYn == 'Y') {  //개인정보 제3자 이용 동의\r\n// \t\t\t\t\t\t$('#agree_03').prop('checked', true);\r\n// \t\t\t\t\t}\r\n\t\t\t\t}\r\n\t\t\t} else if (thirdInfoMode == '3' || thirdInfoMode == '4') {  //예산낭비신고\r\n\t\t\t\t$('#div_thptInfofAgre2').show();  //개인정보 제3자 이용동의 영역 보임\r\n\t\t\t\tif(thirdInfoMode == 3){\r\n\t\t\t\t\t$(\"#p_thptInfofAgreCntnCl\").html(\"예산낭비신고의 이송/이첩, 이관, 업무처리 및 정책 반영을 위해 귀하께서 신고하신 행정기관 외 다른 행정기관에 개인정보가 제공될 수 있습니다.<br><br> 제공되는 개인정보는 신고인 성명, 일반전화, 휴대전화, 전자우편, 주소로 귀하께서 입력하신 정보입니다.<br> 귀하께서는 개인정보 제3자 제공을 동의하지 않을 수 있으며 동의하지 않더라도 신고는 가능합니다.<br> 단, 동의하지 않은 경우 해당기관의 소관업무가 아닌 경우 이송/이첩되지 아니하고 종결처리 될 수 있습니다.\");\r\n\t\t\t\t}else if(thirdInfoMode == 4){\r\n\t\t\t\t\t$(\"#p_thptInfofAgreCntnCl\").html(\"예산절감제안의 이송/이첩, 이관, 업무처리 및 정책 반영을 위해 귀하께서 신고하신 행정기관 외 다른 행정기관에 개인정보가 제공될 수 있습니다.<br><br> 제공되는 개인정보는 신고인 성명, 일반전화, 휴대전화, 전자우편, 주소로 귀하께서 입력하신 정보입니다.<br> 귀하께서는 개인정보 제3자 제공을 동의하지 않을 수 있으며 동의하지 않더라도 신고는 가능합니다.<br> 단, 동의하지 않은 경우 해당기관의 소관업무가 아닌 경우 이송/이첩되지 아니하고 종결처리 될 수 있습니다.\");\r\n\t\t\t\t}\r\n\t\t\t}/*  else if (thirdInfoMode == '4') {  //예산절감제안\r\n\t\t\t\t$('#div_thptInfofAgre3').show();  //개인정보 제3자 이용동의 영역 보임\r\n\t\t\t} */\r\n\r\n\t\t\t//if (frm_lognIndcYn != 'Y') {\r\n\t\t\t//$('#div_loginTitle, #div_loginButton').hide();  //로그인 버튼 숨김\r\n\t\t\t//}\r\n\r\n\t\t\tif ($.chkEmptyVal(dplcSbrbPrvnStvl)) {  //본인 이름 셋\r\n\t\t\t\t$('#str_authTitle').text('본인 인증되었습니다.');\r\n\t\t\t\t$('#div_authBox').hide();\r\n\t\t\t\t$('#div_mbrNm').show();\r\n\t\t\t\t$('#span_mbrNm').css({'fontSize':'16px', 'fontWeight':'bold'}).val('');\r\n\t\t\t\t$('#div_btnNext2').show();\r\n\t\t\t}\r\n\t\t}\r\n\r\n\t\t//저장 버튼 클릭 이벤트\r\n\t\t//$('#btnOpen').on('click', function(){\r\n\t\t//alert('[공지] 본인 인증 모듈 테스트 중이라 불안정할 수 있으니 양해 부탁드립니다.');\r\n\t\t//return;\r\n\t\t//});\r\n\r\n\t\t//sameSite 오류 시 팝업창 호출 20201020-노경용\r\n\t\tvar urlChk=false;\r\n\t\tvar agent = navigator.platform.toLowerCase();\r\n\t\tif((navigator.appName == 'Netscape' && navigator.userAgent.search('Trident') != -1) || (agent.indexOf('msie') != -1)){\r\n\t\t\t$('#alert_wrap').hide();\r\n\t\t}else{\r\n\t\t\tif(opener){\r\n\t\t\t\t$('#alert_wrap').hide();\r\n\t\t\t}else{\r\n\t\t\t\t$('#alert_wrap').show();\r\n\t\t\t\tswitch ($('#frm_frmUrlSn').val()) {\r\n\t\t\t\t\tcase \"1\"  : $('#smesite_pop').html('<span>민원분류</span>'); break;\r\n\t\t\t\t\tcase \"2\"  : $('#smesite_pop').html('<span>민원신청</span>'); break;\r\n\t\t\t\t\tcase \"3\"  : $('#smesite_pop').html('<span>공개민원</span>'); break;\r\n\t\t\t\t\tcase \"4\"  : $('#smesite_pop').html('<span>나의민원</span>'); break;\r\n\t\t\t\t\tcase \"5\"  : $('#smesite_pop').html('<span>민원FAQ</span>'); break;\r\n\t\t\t\t\tcase \"6\"  : $('#smesite_pop').html('<span>일반제안</span>'); break;\r\n\t\t\t\t\tcase \"7\"  : $('#smesite_pop').html('<span>공개제안</span>'); break;\r\n\t\t\t\t\tcase \"8\"  : $('#smesite_pop').html('<span>나의제안</span>'); break;\r\n\t\t\t\t\tcase \"10\" : $('#smesite_pop').html('<span>우수제안</span>'); break;\r\n\t\t\t\t\tcase \"11\" : $('#smesite_pop').html('<span>대화형목록</span>'); break;\r\n\t\t\t\t\tcase \"12\" : $('#smesite_pop').html('<span>온라인공청회</span>'); break;\r\n\t\t\t\t\tcase \"13\" : $('#smesite_pop').html('<span>설문형목록</span>'); break;\r\n\t\t\t\t\tcase \"14\" : $('#smesite_pop').html('<span>입법예고</span>'); break;\r\n\t\t\t\t\tcase \"15\" : $('#smesite_pop').html('<span>행정예고</span>'); break;\r\n\t\t\t\t\tcase \"16\" : $('#smesite_pop').html('<span>입법·행정예고</span>'); break;\r\n\t\t\t\t\tcase \"17\" : $('#smesite_pop').html('<span>공모제안</span>');  break;\r\n\t\t\t\t\tcase \"18\" : $('#smesite_pop').html('<span>민원·정책Q&A</span>'); break;\r\n\t\t\t\t\tcase \"24\" : $('#smesite_pop').html('<span>외국어민원신청</span>'); break;\r\n\t\t\t\t\tcase \"25\" : $('#smesite_pop').html('<span>나의외국어민원</span>'); break;\r\n\t\t\t\t\tcase \"21\" : $('#smesite_pop').html('<span>예산낭비신고</span>'); break;\r\n\t\t\t\t\tcase \"22\" : $('#smesite_pop').html('<span>나의신고</span>'); break;\r\n\t\t\t\t\tcase \"23\" : $('#smesite_pop').html('<span>예산절감제안</span>'); break;\r\n\t\t\t\t\tcase \"19\" : $('#smesite_pop').html('<span>민원Q&A</span>'); break;\r\n\t\t\t\t\tcase \"20\" : $('#smesite_pop').html('<span>정책Q&A</span>'); break;\r\n\t\t\t\t\tcase \"32\" : $('#smesite_pop').html('<span>온라인상담신청</span>'); break;\r\n\t\t\t\t\tcase \"33\" : $('#smesite_pop').html('<span>온라인상담목록</span>'); break;\r\n\t\t\t\t\tdefault: urlChk=true; break;\r\n\t\t\t\t}\r\n\t\t\t}\r\n\t\t}\r\n\t\tvar returnUrlval = \"\";\r\n\t\tif(urlChk){\r\n\t\t\treturnUrlval = 'https://www.epeople.go.kr'+returnUrl;\r\n\t\t}else{\r\n\t\t\tif($('#frm_frmAllUrl').val()==\"\"){\r\n\t\t\t\treturnUrlval = 'https://www.epeople.go.kr';\r\n\t\t\t}else{\r\n\t\t\t\treturnUrlval = $('#frm_frmAllUrl').val();\r\n\t\t\t}\r\n\t\t}\r\n\t\t$('#smesite_pop').on('click', function(){\r\n\t\t\tvar size = \"width='800',height='800',scrollbars=1\";\r\n\t\t\twindow.open( returnUrlval , \"_blank\", size);\r\n\t\t});\r\n\r\n\t\t$('#agree_01').focus();\r\n\t});  //end ready\r\n\r\n\r\n\t//제3자 동의 체크\r\n\tfunction fn_chkAgree() {\r\n\t\treturn true;\r\n\r\n\t\t//선택항목 동의 체크\r\n\t\t/* if (!$('#agree_02').prop('checked')) {\r\n\t\t\tjAlert('선택항목 수집 및 이용 동의에 체크하셔야 합니다.');\r\n\t\t\t$('#agree_02').focus();\r\n\t\t\treturn false;\r\n\t\t} else {\r\n\t\t\t$('#indvifChceItmAgreYn').val('Y');\r\n\t\t\treturn true;\r\n\t\t} */\r\n\r\n\t\t//선택사항 체크\r\n\t\t/* if (!$('#agree_03').prop('checked')) {\r\n\t\t\tjAlert('개인정보 제3자 이용 동의 방침에 동의하셔야 합니다.');\r\n\t\t\t$('#agree_03').focus();\r\n\t\t\treturn false;\r\n\t\t} else {\r\n\t\t\t$('#thptInfofAgreYn').val('Y');\r\n\t\t\treturn true;\r\n\t\t} */\r\n\r\n\t\t//var url = '/frm/pttn/pttnRqstInfo.paid?frmMenuMngNo=' + frm_frmMenuMngNo;  //민원 신청 기본 페이지\r\n\t\t//$(location).attr('href', url);\r\n\t\t//$('#agreeFrm').attr({'action' : url, 'method' : 'get'}).submit();\r\n\t}\r\n\r\n\t//간편인증 로그인\r\n\tfunction fn_prcsLoginSimple() {\r\n\t\tif (fn_chkAgree()) {\r\n\t\t\tvar param = {\"returnUrl\" : returnUrl, \"callBackFncNm\" : \"fn_nmbrLognPrcs\"};\r\n\t\t\t//v1.0\r\n\t\t\t//gfn_openPopupPost(\"simpleCrtfPopup\", param, \"simpleCrtfPopup\", \"/nep/crtf/simpleCrtfPopup.npaid\", 661, 666);\r\n\t\t\t//v1.5\r\n\t\t\t//gfn_openPopupPost(\"simpleCrtfPopup\", param, \"simpleCrtfPopup\", \"/nep/crtf/simpleCrtfPopup15.npaid\", 661, 662);\r\n\t\t\t//v1.51\r\n\t\t\tgfn_openPopupPost(\"simpleCrtfPopup\", param, \"simpleCrtfPopup\", \"/nep/crtf/simpleCrtfPopup15.npaid\", 838, 640);\r\n\t\t}\r\n\t}\r\n\r\n\t//모바일신분증 로그인\r\n\tfunction fn_prcsLoginMobile() {\r\n\t\tif (fn_chkAgree()) {\r\n\t\t\tvar param = {\"returnUrl\" : returnUrl, \"callBackFncNm\" : \"fn_nmbrLognPrcs\", \"mobileYn\": \"false\"};\r\n\t\t\tgfn_openPopupPost(\"mobileCrtfPopup\", param, \"mobileCrtfPopup\", \"/nep/crtf/mobilCrtPopup.npaid\", 838, 615);\r\n\t\t}\r\n\t}\r\n\r\n\t//아이핀\r\n\tfunction fn_ipinModulCheck() {\r\n\t\tif (fn_chkAgree()) {\r\n\t\t\tvar param = {\"returnUrl\" : returnUrl, \"callBackFncNm\" : \"fn_nmbrLognPrcs\"};\r\n\t\t\tgfn_openPopupPost(\"ipinCrtfPopup\", param, \"ipinCrtfPopup\", \"/nep/crtf/ipinCrtfPopup.npaid\", 480, 520);\r\n\t\t}\r\n\t}\r\n\r\n\t//공동인증서(구 공인인증서)\r\n\tfunction fn_ogcrCheck() {\r\n\t\t// 실명인증시스템(행정안전부) 작업\r\n\t\tvar startDay  = new Date(2020, 09, 10);\t// 08->09월이 됨. 2020.10.10일\r\n\t\tvar startTime = new Date(startDay.getTime() );// 60000(1초)\r\n\t\tvar endDay  = new Date(2020, 09, 10);\r\n\t\tvar endTime = new Date(endDay.getTime()\t+ 20*60*60000 );// 20시\r\n\t\tvar now = new Date();\r\n\t\t//alert(\"startTime: \"+startTime +\",endTime: \"+endTime);\r\n\t\tvar aMessage =\"실명인증시스템(행정안전부) 점검으로인해 한시적으로 공동인증서(구 공인인증서) 이용이 중단됩니다.<br/><br/>중단시간: 2020.10.10.(토) 00:00 ~ 20:00\";\r\n\r\n\t\tif(startTime <= now && now < endTime) {\r\n\t\t\tjAlert(aMessage);\r\n\t\t\treturn;\r\n\t\t}\r\n\r\n\t\tif (fn_chkAgree()) {\r\n\t\t\tvar param = {\"callId\" : \"LOGIN_CHECK\", \"returnUrl\" : returnUrl, \"callBackFncNm\" : \"fn_nmbrLognPrcs\"};\r\n\t\t\t//gfn_openPopupPost(\"orctInfoCrtfPopup\", param, \"orctInfoCrtfPopup\", \"/nep/crtf/orctInfoCrtfPopup.npaid\", 480, 600);\r\n\t\t\tgfn_openPopupPost(\"orctInfoCrtfPopupRenew\", param, \"orctInfoCrtfPopupRenew\", \"/nep/crtf/orctInfoCrtfPopupRenew.npaid\", 480, 600);\r\n\t\t}\r\n\t}\r\n\r\n\t//금융인증서\r\n\tfunction fn_ficrCheck() {\r\n\t\t// 실명인증시스템(행정안전부) 작업\r\n\t\tvar startDay  = new Date(2020, 09, 10);\t// 08->09월이 됨. 2020.10.10일\r\n\t\tvar startTime = new Date(startDay.getTime() );// 60000(1초)\r\n\t\tvar endDay  = new Date(2020, 09, 10);\r\n\t\tvar endTime = new Date(endDay.getTime()\t+ 20*60*60000 );// 20시\r\n\t\tvar now = new Date();\r\n\t\t//alert(\"startTime: \"+startTime +\",endTime: \"+endTime);\r\n\t\tvar aMessage =\"실명인증시스템(행정안전부) 점검으로인해 한시적으로 금융인증서 이용이 중단됩니다.<br/><br/>중단시간: 2020.10.10.(토) 00:00 ~ 20:00\";\r\n\r\n\t\tif(startTime <= now && now < endTime) {\r\n\t\t\tjAlert(aMessage);\r\n\t\t\treturn;\r\n\t\t}\r\n\r\n\t\tif (fn_chkAgree()) {\r\n\t\t\tvar param = {\"callId\" : \"LOGIN_CHECK\", \"returnUrl\" : returnUrl, \"callBackFncNm\" : \"fn_nmbrLognPrcs\"};\r\n\t\t\tgfn_openPopupPost(\"fictInfoCrtfPopup\", param, \"fictInfoCrtfPopup\", \"/nep/crtf/fictInfoCrtfPopup.npaid\", 480, 600);\r\n\t\t}\r\n\t}\r\n\r\n\t//휴대전화\r\n\tfunction fn_phoneCrtfcCheck() {\r\n\t\tif (fn_chkAgree()) {\r\n\t\t\tvar param = {\"returnUrl\" : returnUrl, \"callBackFncNm\" : \"fn_nmbrLognPrcs\"};\r\n\t\t\tgfn_openPopupPost(\"cpCrtfPopup\", param, \"cpCrtfPopup\", \"/nep/crtf/cpCrtfPopup.npaid\", 500, 600);\r\n\t\t}\r\n\t}\r\n\r\n\t//외국인등록번호\r\n\tfunction fn_undrtkrNoCheck() {\r\n\t\tif (fn_chkAgree()) {\r\n\t\t\tvar param = {\"returnUrl\" : returnUrl, \"callBackFncNm\" : \"fn_nmbrLognPrcs\"};\r\n\t\t\tgfn_openPopupPost(\"inhbFgnoInfoCrtfPopup\", param, \"inhbFgnoInfoCrtfPopup\", \"/nep/crtf/inhbFgnoInfoCrtfPopup.npaid\", 550, 450);\r\n\t\t}\r\n\t}\r\n\r\n\t//로그인 성공시 페이지 이동\r\n\tfunction fn_nmbrLognPrcs(param) {\r\n\t\t$('#loginMode').val('frm');\r\n\t\t$('#returnUrl').val(returnUrl);\r\n\t\tif($('#agree_03').prop('checked')){\r\n\t\t\t$('#thptInfofAgreYn').val(\"Y\");\r\n\t\t\t$('#frm_thptInfofAgreYn').val(\"Y\");\r\n\t\t}\r\n\t\tif($('#agree_05').prop('checked')){\r\n\t\t\t$('#thptInfofAgreYn').val(\"N\");\r\n\t\t\t$('#frm_thptInfofAgreYn').val(\"Y\");\r\n\t\t}\r\n\t\t/* 프레임 관련 변수 추가 하여 submit 20200413 노경용 */\r\n\t\tvar action = $.trim(param.returnUrl);\r\n\t\tvar form = $(\"form#frmMngInfoVO\");\r\n\t\tform.attr(\"action\", action).submit();\r\n\t}\r\n\r\n\t//로그인 페이지로 이동\r\n\tfunction fn_moveLogin() {\r\n\t\tif (fn_chkAgree()) {\r\n\t\t\tvar url = '/frmSub/crtf/frmUserLogn.npaid?loginMode=frm&returnUrl=' + returnUrl;\r\n\t\t\t$('#loginMode').val('frm');\r\n\t\t\t$('#returnUrl').val(returnUrl);\r\n\t\t\t$('#agreeFrm').attr({'action' : url, 'method' : 'get'}).submit();\r\n\t\t}\r\n\t}\r\n\r\n\t//get returnUrl\r\n\tfunction fn_getReturnUrl() {\r\n\t\tvar returnUrl = '';\r\n\r\n\t\tif ($.chkEmptyVal(requestUri)) {\r\n\t\t\tif (requestUri.indexOf('pttnRqstInfo.') > -1) {  //민원신청\r\n\t\t\t\tthirdInfoMode = '1';\r\n\t\t\t\treturnUrl = \"/frmSub/pttn/gnrlPttn/FrmPttnRqstWrtnInfo.paid\";\r\n\t\t\t} else if (requestUri.indexOf('gnrlPrplRqstInfo.') > -1) {  //일반제안\r\n\t\t\t\tthirdInfoMode = '2';\r\n\t\t\t\treturnUrl = \"/frmSub/prpl/selectGnrlPrpslRqstPage.paid\";\r\n\t\t\t} else if (requestUri.indexOf('bdgtWstRqstInfo.') > -1) {  //예산낭비신고\r\n\t\t\t\tthirdInfoMode = '3';\r\n\t\t\t\treturnUrl = \"/frmSub/bdgtWst/selectBdgtWstRqstPage.paid\";\r\n\t\t\t} else if (requestUri.indexOf('bdgtRdcnPrplInfo.') > -1) {  //예산절감제안\r\n\t\t\t\tthirdInfoMode = '4';\r\n\t\t\t\treturnUrl = \"/frmSub/bdgtWst/selectBdgtRdcnPrpslRqstPage.paid\";\r\n\t\t\t} else if (requestUri.indexOf('frmPttnClsfList.') > -1) {  //메뉴분류에서 민원신청으로 넘어온 경우\r\n\t\t\t\tthirdInfoMode = '5';\r\n\t\t\t\treturnUrl = \"/frmSub/pttn/gnrlPttn/FrmPttnRqstWrtnInfo.paid\";\r\n\t\t\t} else if(requestUri.indexOf('ppaRqst.') > -1){\t//적극행정\r\n\t\t\t\tthirdInfoMode = '5';\r\n\t\t\t\treturnUrl = \"/frmSub/ppa/frmPpaRqstWrtnInfo.paid\";\r\n\t\t\t} else if(requestUri.indexOf('psaStmt.') > -1){ //소극신고\r\n\t\t\t\tthirdInfoMode = '5';\r\n\t\t\t\treturnUrl = \"/frmSub/psa/frmPsaStmtWrtnCont.paid\";\r\n\t\t\t} else if(requestUri.indexOf('psaResttemnt.') > -1){ //소극재신고\r\n\t\t\t\tthirdInfoMode = '5';\r\n\t\t\t\treturnUrl = \"/frmSub/psa/frmPsaResttemnt.paid\";\r\n\t\t\t}\r\n\r\n\t\t\telse {  //frmUserLogn.npaid (나의민원같이 .paid여서 로그인 페이지로 넘어온 경우)\r\n\t\t\t\tthirdInfoMode = '0';\r\n\t\t\t\treturnUrl = '';\r\n\t\t\t}\r\n\t\t}\r\n\t\t//return encodeURIComponent(returnUrl);\r\n\t\treturn returnUrl;\r\n\t}\r\n\r\n\t//다음 버튼 클릭 이벤트\r\n\tfunction fn_moveNext() {\r\n\r\n\t\tif(returnUrl != \"/frmSub/bdgtWst/selectBdgtWstRqstPage.paid\" && returnUrl != \"/frmSub/bdgtWst/selectBdgtRdcnPrpslRqstPage.paid\"){\r\n\t\t\tif($('#agree_03').prop('checked')){\r\n\t\t\t\t$('#thptInfofAgreYn').val(\"Y\");\r\n\t\t\t\t$('#frm_thptInfofAgreYn').val(\"Y\");\r\n\t\t\t}\r\n\t\t\tif($('#agree_05').prop('checked')){\r\n\t\t\t\t$('#thptInfofAgreYn').val(\"N\");\r\n\t\t\t\t$('#frm_thptInfofAgreYn').val(\"Y\");\r\n\t\t\t}\r\n\t\t}else{\r\n\t\t\tif($('#agree_04').prop('checked')){\r\n\t\t\t\t$('#thptInfofAgreYn').val(\"Y\");\r\n\t\t\t\t$('#frm_thptInfofAgreYn').val(\"Y\");\r\n\t\t\t}\r\n\t\t}\r\n\r\n\t\tif ($.chkEmptyVal($('#span_mbrNm').val())) {\r\n\t\t\t//로딩바 추가 20200623-노경용\r\n\t\t\t$('.loading_submit').show();\r\n\t\t\t/* 프레임 관련 변수 추가 하여 submit 20200413 노경용 */\r\n\t\t\tvar action = $.trim(returnUrl);\r\n\t\t\tvar form = $(\"form#frmMngInfoVO\");\r\n\t\t\tform.attr(\"action\", action).submit();\r\n\t\t} else {\r\n\t\t\tjAlert('본인 인증이 필요합니다.');\r\n\t\t\treturn;\r\n\t\t}\r\n\t}\r\n\r\n\t// SNS 간편 로그인\r\n\tfunction fn_snsLogin(socialType) {\r\n// \t\tgfn_openPopupPost(\"snsViewer\", '' ,\"snsViewer\", \"about:blank\", 600, 550);\r\n\t\t$('#snsFrm input[name=socialType]').val(socialType);\r\n\t\t$('#snsFrm input[name=returnUrl]').val(socialType);\r\n\t\t$('#snsFrm input[name=checkType]').val('add');\r\n// \t\t$(\"#snsFrm\").attr(\"target\", \"snsViewer\");\r\n\t\t$('#snsFrm').attr('action', '/nep/crtf/selectSocialLogn.npaid');\r\n\t\t$('#snsFrm').submit();\r\n\t}\r\n\r\n
                </script>\n<form id=\"agreeFrm\" name=\"agreeFrm\">\n
                    <!-- <input type=\"hidden\" id=\"indvifSntlItmAgreYn\" name=\"indvifSntlItmAgreYn\" value=\"N\" />\r\n\t<input type=\"hidden\" id=\"thptInfofAgreYn\" name=\"thptInfofAgreYn\" value=\"N\" /> -->\n<input name=\"_csrf\" type=\"hidden\" value=\"d4e8959f-0d9b-48f1-89d0-8559aafaae91\" />\n<input id=\"loginMode\" name=\"loginMode\" type=\"hidden\" value=\"\" />\n<input id=\"returnUrl\" name=\"returnUrl\" type=\"hidden\" value=\"\" />\n
                </form>\n<header id=\"subTit\" style=\"display:none;\">\n<h3>개인 정보 수집 및 이용 안내</h3>\n</header>\n<article id=\"txt\">\n<form action=\"\" id=\"frmMngInfoVO\" method=\"post\" name=\"frmMngInfoVO\">\n
                        <!-- 20200408/프레임통합 노경용/프레임통합메뉴 관련 변수 -->\n<input id=\"frm_frmMenuMngNo\" name=\"frm_frmMenuMngNo\" type=\"hidden\" value=\"WBF-1202-000044\" />\n<input id=\"frm_instCd\" name=\"frm_instCd\" type=\"hidden\" value=\"3060000\" />\n<input id=\"frm_clsfAplcYn\" name=\"frm_clsfAplcYn\" type=\"hidden\" value=\"N\" />\n<input id=\"frm_rcptPathInstCd\" name=\"frm_rcptPathInstCd\" type=\"hidden\" value=\"3060000\" />\n<input id=\"frm_frmUrlSn\" name=\"frm_frmUrlSn\" type=\"hidden\" value=\"21\" />\n<input id=\"frm_frmAllUrl\" name=\"frm_frmAllUrl\" type=\"hidden\" value=\"https://www.epeople.go.kr/frm/bdgt/bdgtWstRqstInfo.npaid?frmMenuMngNo=WBF-1202-000044\" />\n<input id=\"frm_prcsInstChcePsblYn\" name=\"frm_prcsInstChcePsblYn\" type=\"hidden\" value=\"N\" />\n<input id=\"frm_thptInfofAgreYn\" name=\"frm_thptInfofAgreYn\" type=\"hidden\" value=\"\" />\n<input id=\"frmDsgnType\" name=\"frmDsgnType\" type=\"hidden\" value=\"\" />\n<input id=\"frm_frmMenuClsfCd\" name=\"frm_frmMenuClsfCd\" type=\"hidden\" value=\"\" />\n<input id=\"frm_chrgDeptCd\" name=\"frm_chrgDeptCd\" type=\"hidden\" value=\"\" />\n<input id=\"frm_pttnDrctRcptYn\" name=\"frm_pttnDrctRcptYn\" type=\"hidden\" value=\"\" />\n<input id=\"frm_rcptTySctnCd\" name=\"frm_rcptTySctnCd\" type=\"hidden\" value=\"\" />\n<input id=\"frm_clsfRpsnNm\" name=\"frm_clsfRpsnNm\" type=\"hidden\" value=\"\" />\n<input id=\"frm_frmMngrCnt\" name=\"frm_frmMngrCnt\" type=\"hidden\" value=\"0\" />\n<input id=\"frm_sysCrtnMngrIdCnt\" name=\"frm_sysCrtnMngrIdCnt\" type=\"hidden\" value=\"0\" />\n<input id=\"frm_areaSntlYn\" name=\"frm_areaSntlYn\" type=\"hidden\" value=\"\" />\n<input id=\"frm_atchFileSntlYn\" name=\"frm_atchFileSntlYn\" type=\"hidden\" value=\"\" />\n<input id=\"frm_drqstrInfoIndcYn\" name=\"frm_drqstrInfoIndcYn\" type=\"hidden\" value=\"\" />\n<input id=\"frm_dpttnrInfoSntlYn\" name=\"frm_dpttnrInfoSntlYn\" type=\"hidden\" value=\"\" />\n<input id=\"frm_pttnSctnCd\" name=\"frm_pttnSctnCd\" type=\"hidden\" value=\"80030001\" />\n<input id=\"frm_scryPttnSctnCd\" name=\"frm_scryPttnSctnCd\" type=\"hidden\" value=\"0A070002\" />\n<input id=\"frm_gdncWrdsUseYn\" name=\"frm_gdncWrdsUseYn\" type=\"hidden\" value=\"\" />\n<input id=\"frm_egppYn\" name=\"frm_egppYn\" type=\"hidden\" value=\"N\" />\n<input id=\"frm_cnrsYn\" name=\"frm_cnrsYn\" type=\"hidden\" value=\"Y\" />\n<input id=\"frm_addnCltnItmUseYn\" name=\"frm_addnCltnItmUseYn\" type=\"hidden\" value=\"\" />\n<input id=\"frm_pttnClsfCd\" name=\"frm_pttnClsfCd\" type=\"hidden\" value=\"\" />\n<input id=\"frm_prcsTmltNumd\" name=\"frm_prcsTmltNumd\" type=\"hidden\" value=\"\" />\n<input id=\"frm_basePrcsPrd\" name=\"frm_basePrcsPrd\" type=\"hidden\" value=\"7\" />\n<input id=\"frm_menuCd\" name=\"frm_menuCd\" type=\"hidden\" value=\"BW001\" />\n<input id=\"frm_proPotMngrIdCnt\" name=\"frm_proPotMngrIdCnt\" type=\"hidden\" value=\"0\" />\n<input id=\"frm_ablYn\" name=\"frm_ablYn\" type=\"hidden\" value=\"N\" />\n<input id=\"acesMode\" name=\"acesMode\" type=\"hidden\" value=\"frm\" />\n<input id=\"frm_lwsInstNm\" name=\"frm_lwsInstNm\" type=\"hidden\" value=\"중랑구\" />\n<input id=\"frm_cntnCl\" name=\"frm_cntnCl\" type=\"hidden\" value=\"\" />\n<input id=\"frm_oppbYn\" name=\"frm_oppbYn\" type=\"hidden\" value=\"\" />\n<input id=\"frm_pttnKndCd\" name=\"frm_pttnKndCd\" type=\"hidden\" value=\"90100010\" />\n<input id=\"thptInfofAgreYn\" name=\"thptInfofAgreYn\" type=\"hidden\" value=\"\">\n</input>
                    </form>\n<div class=\"cl_type\" id=\"div_frmDsgnType\">
                        <!-- 프레임 디자인 타입 설정 -->\n<div class=\"default_order\">\n<div class=\"order_item icon_1 on\">
                                \n<span title=\"현재 신청서 작성 단계\">1 신청서 작성</span>\n</div>\n<div class=\"order_item icon_2\" id=\"div_step2\">\n<span title=\"기관선택 단계\">2 기관선택</span>\n</div>\n<div class=\"order_item icon_3\">\n<span id=\"span_step3\" title=\"신청완료 단계\">3 신청완료</span>\n
                            </div>\n</div>\n<div id=\"div_frmMenuClsfCd\" style=\"display:none;\"></div>\n
                        <!--\r\n\t\t<div id=\"alert_wrap\" style=\"display:none;\">\r\n\t\t    <div class=\"popup_wrap_blank\">\r\n\t\t        <div class=\"pl_20\">\r\n\t\t            <p><h5><span class=\"orange\">※ 일부 브라우저에서는 제조사의 강화된 보안정책으로 인해, 정상적인 이용에 제한이 있을 수 있습니다.</span></h5></p>\r\n\t\t            <p><h5><span class=\"orange\"> <button type=\"button\" class=\"bbs_btn fill\" id=\"smesite_pop\"><span>나의신문고</span></button>&nbsp;&nbsp;버튼을 누르시거나, 국민신문고(www.epeople.go.kr)사이트를 이용하시기 바랍니다.</span></h5></p>\r\n\t\t        </div>\r\n\t\t    </div>\r\n\t\t</div>\r\n\t\t -->\n
                        <div class=\"login_box mb_50 mt_0\">\n
                            <!-- \t\t\t<div class=\"tit_box\">\r\n                            <strong>본인 인증</strong>\r\n                        </div>\r\n                        <div class=\"form_box\">\r\n                            <div class=\"be_join\">\r\n                                <a href=\"javascript:void(0);\" class=\"be_01\" onclick=\"fn_ipinModulCheck();\"><span>아이핀</span></a>\r\n                                <a href=\"javascript:void(0);\" class=\"be_02\" onclick=\"fn_ogcrCheck();\"><span>공동인증서(구 공인인증서)</span></a>\r\n                                <a href=\"javascript:void(0);\" class=\"be_03\" onclick=\"fn_phoneCrtfcCheck();\"><span>휴대전화</span></a>\r\n                                <a href=\"javascript:void(0);\" class=\"be_04\" onclick=\"fn_undrtkrNoCheck();\"><span>외국인등록번호</span></a>\r\n                            </div>\r\n                        </div> -->\n
                            <div class=\"titBox slideTit\">\n<strong id=\"str_authTitle\">본인 인증(비회원 로그인)</strong>\n
                            </div>\n<div class=\"slideBox\">\n<a class=\"slideBtn on\" href=\"javaScript:void(0);\" id=\"btnOpen\">열기</a>\n<div class=\"form_box\">\n<div class=\"bSch_row\" id=\"div_mbrNm\" style=\"display:none;\">\n<div class=\"bSch_col\">
                                            \n<strong>신청인 이름 : </strong><input disabled=\"disabled\" id=\"span_mbrNm\" title=\"신청인 이름\" type=\"text\" value=\"\" />\n<span id=\"div_btnNext2\" style=\"display:none;float:right\">\n<button class=\"btn fill\" id=\"btnNext\" onclick=\"fn_moveNext();\" type=\"button\"><span>다음</span></button>\n</span>\n
                                        </div>\n</div>\n<div class=\"be_join\" id=\"div_authBox\">\n<a class=\"be_00\" href=\"javascript:void(0);\" onclick=\"fn_prcsLoginSimple()\" title=\"간편인증 새창\"><span>간편인증</span></a>\n<a class=\"be_06\" href=\"javascript:void(0);\" onclick=\"fn_prcsLoginMobile()\" title=\"모바일신분증 새창\"><span>모바일신분증</span></a>\n<a class=\"be_01\" href=\"javascript:void(0);\" onclick=\"fn_ipinModulCheck();\" title=\"아이핀 인증 새창 열림\"><span>아이핀</span></a>\n<a class=\"be_05\" href=\"javascript:void(0);\" onclick=\"fn_ficrCheck();\" title=\"금융인증서 인증 새창 열림\"><span>금융인증서</span></a>\n<a class=\"be_02\" href=\"javascript:void(0);\" onclick=\"fn_ogcrCheck();\" title=\"공동인증서(구 공인인증서) 인증 새창 열림\"><span>공동인증서(구 공인인증서)</span></a>\n<a class=\"be_03\" href=\"javascript:void(0);\" onclick=\"fn_phoneCrtfcCheck();\" title=\"휴대전화 인증 새창 열림\"><span>휴대전화</span></a>\n
                                        <!-- <a href=\"javascript:void(0);\" class=\"be_04\" onclick=\"fn_undrtkrNoCheck();\" title=\"외국인등록번호 인증 새창 열림\" ><span>외국인등록번호</span></a> -->\n
                                    </div>\n</div>\n</div>\n
                            <!-- SNS 간편 로그인 시작 -->\n
                            <!-- SNS 간편 로그인 끝 -->\n<div class=\"titBox slideTit\" id=\"div_loginTitle\" style=\"display:none;\">\n<strong>국민신문고 로그인</strong>\n</div>\n<div class=\"btnArea center\" id=\"div_loginButton\" style=\"display:none;\">
                                \n<button class=\"btn gray\" id=\"btnLogin\" onclick=\"fn_moveLogin();\" type=\"button\"><span>로그인</span></button><br /><br />\n<span id=\"str_welcome\">※ 로그인을 하시면 더 많은 정보를 편리하게 이용하실 수 있습니다.</span>\n
                            </div>\n
                        </div>\n<div class=\"btnArea right\" id=\"div_btnNext\" style=\"display:none;\">
                            \n<button class=\"btn fill\" id=\"btnNext\" onclick=\"fn_moveNext();\" type=\"button\"><span>다음</span></button>\n
                        </div>\n
                    </div>\n
                    <!-- 로딩 화면 추가 20200618-노경용 -->\n<div class=\"loading_submit\" style=\"display:none;\">\n<div class=\"apload_ing\"></div>\n<div class=\"load_box\">
                            \n<span><img alt=\"불러오는 중\" src=\"/resource/images/paid/biz/content/load_ing.png\" /></span>\n<strong>화면을 불러오는 중</strong>\n
                            <p>요청하신 화면을 불러오는 중입니다. 잠시만 기다려주십시오.</p>\n</div>\n</div>\n
                </article>\n</section>\n</main>\n
    </div>\n
    <!-- 1 : 개인정보 스크립트 -->\n<script src=\"/resource/app/applex_wdigm_html5/applex_local.js?version=1.08\" type=\"text/javascript\"></script>\n
    <!-- 2 : 첨부파일 변환 스크립트 -->\n<iframe class=\"uploadIFrame1\" id=\"uploadIFrame1\" name=\"uploadIFrame1\" style=\"display: none; visibility: hidden;\" title=\"첨부파일 변환\"></iframe>\n
    <!-- 3 : 개인정보 차단 스크립트 -->\n
    <!-- 4 : onchang 함수 -->\n
    <!-- 5 : 첨부파일 변환 알림 문구 -->\n
    <!-- <div id=\"applex_wdigm_html5_waiting\"></div> -->\n
    <!-- 2025-09-04 15:55:22 -->\n
    <!-- euser34 -->\n
</body>\n

</html>"""

# %%
data.replace("\n","")
# Out:
# '<!DOCTYPE html><html lang="ko"><head>    <meta charset="utf-8" />    <meta content="width=device-width, initial-scale=1.0" name="viewport" />    <meta content="_csrf" name="_csrf_parameter">    <meta content="X-CSRF-TOKEN" name="_csrf_header">    <meta content="d4e8959f-0d9b-48f1-89d0-8559aafaae91" name="_csrf" />    <meta content="ie=edge" http-equiv="X-UA-Compatible" /><title>국민신문고</title>    <link href="/resource/css/paid/nep/pot/css.css?version=1.01" rel="stylesheet" type="text/css" />    <link href="/resource/js/paid/cmmn/mCustomScrollbar/jquery.mCustomScrollbar.css" rel="stylesheet" type="text/css" />    <link href="/resource/css/paid/cmmn/jAlert.css" rel="stylesheet" type="text/css" /><script type="text/javascript">                r\\ n\\ tvar contexts = "";\r\t\r\t\r\tvar exnMnTxt = "jpg, jpeg, gif, png, bmp, txt, pdf, hwp, gul, docx, doc, zip, xls, xlsx, ppt, pptx, mp4, avi, wmv, asf, flv, mov, mkv, mpeg, mpg, 3gp, wmv, webm, ogm, asx, m2t, m2ts, mts, tif, tiff, wav, mp3, 3ga, m4a, amr, mp2, hwpx, odt, csv";\r\tvar exnMnArr = ["jpg","jpeg","gif","png","bmp","txt","pdf","hwp","gul","docx","doc","zip","xls","xlsx","ppt","pptx","mp4","avi","wmv","asf","flv","mov","mkv","mpeg","mpg","3gp","wmv","webm","ogm","asx","m2t","m2ts","mts","tif","tiff","wav","mp3","3ga","m4a","amr","mp2","hwpx","odt","csv"];\r\tvar JBOSS_NODE_NAME = \'euser34\';\r    </script><script src="/resource/js/paid/cmmn/jquery-1.12.4.min.js" type="text/javascript"></script><script src="/resource/js/paid/cmmn/jquery-ui.min.js" type="text/javascript"></script><script src="/resource/js/paid/cmmn/jquery.cookie.js" type="text/javascript"></script><script src="/resource/js/paid/cmmn/bootstrap.min.js" type="text/javascript"></script><script src="/resource/js/paid/cmmn/loading.js" type="text/javascript"></script><script src="/resource/js/paid/cmmn/sendAjaxReq.js" type="text/javascript"></script><script src="/resource/js/paid/cmmn/jquery.form.js" type="text/javascript"></script><script src="/resource/js/paid/cmmn/mCustomScrollbar/jquery.mCustomScrollbar.concat.min.js" type="text/javascript">    </script><script src="/resource/js/paid/cmmn/pgwslideshow/pgwslideshow.min.js" type="text/javascript">    </script><script src="/resource/js/paid/nep/pot/common.js" type="text/javascript"></script><script src="/resource/js/paid/cmmn/common.js" type="text/javascript"></script>    <!-- [if lt IE 9]>\r<script type="text/javascript" src="/resource/js/paid/cmmn/html5shiv.min.js"></script>\r<![endif]-->    <script src="/resource/js/paid/cmmn/jquery.money.plus.js" type="text/javascript"></script><script src="/resource/js/paid/cmmn/jquery.alphanumeric.js" type="text/javascript"></script><script src="/resource/js/paid/cmmn/jquery.alerts.js" type="text/javascript"></script><script src="/resource/js/paid/cmmn/validation.js" type="text/javascript"></script><script src="/resource/js/paid/nep/cmmn/netfunnel/netfunnel.js?ver=1.0" type="text/javascript"></script><script src="/resource/js/paid/nep/cmmn/netfunnel/nfnSkin.js?ver=1.0" type="text/javascript"></script><script src="/resource/js/paid/cmmn/common.popup.js" type="text/javascript"></script><script type="text/javascript">                r\\ n\\ tvar acesMode = \'frm\'; //프레임 접근 구분자\r\t$(function(){\r\t\tif (acesMode == \'frm\') {\r\t\t\t$(\'#contentWrap\').addClass(\'full\');  //프레임일 경우 화면 레이아웃 Full\r\t\t}\r\r\t\t//$(document).attr(\'title\', $(document).attr(\'title\') + \' | \' + JBOSS_NODE_NAME);\r\t});\r    </script></meta>    </meta></head><body><div class="loading black" style="position:fixed; width:100%; height:auto; min-height:100%; z-index:100; top:0; left:0; display:block; opacity:.6;"><div style="width:100%; height:100%; top:50%; left:50%; position:absolute;">            <span style="display:table-cell; text-align:center; vertical-align:middle;"><img alt="로딩중" src="/resource/images/paid/cmmn/bg_progress.gif" /></span>        </div></div><div id="wrap">        <!-- 세션에 접근 시스템 구분자가 프레임이 아닐 경우(프레임 통합 메뉴로 접근시 세션에 접근 시스템 구분자를 추 ...

# %%
print(data)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
#
#
# <head>
#
#     <meta charset="utf-8" />
#
#     <meta content="width=device-width, initial-scale=1.0" name="viewport" />
#
#     <meta content="_csrf" name="_csrf_parameter">
#     <meta content="X-CSRF-TOKEN" name="_csrf_header">
#     <meta content="d4e8959f-0d9b-48f1-89d0-8559aafaae91" name="_csrf" />
#
#     <meta content="ie=edge" http-equiv="X-UA-Compatible" />
# <title>국민신문고</title>
#
#     <link href="/resource/css/paid/nep/pot/css.css?version=1.01" rel="stylesheet" type="text/css" />
#
#     <link href="/resource/js/paid/cmmn/mCustomScrollbar/jquery.mCustomScrollbar.css" rel="stylesheet" type="text/css" />
#
#     <link href="/resource/css/paid/cmmn/jAlert.css" rel="stylesheet" type="text/css" />
# <script type="text/javascript">
#                 r\ n\ tvar contexts = "";
#
#
# 	var exnMnTxt = "jpg, jpeg, gif, png, bmp, txt, pdf, hwp, gul, docx, doc, zip, xls, xlsx, ppt, pptx, mp4, avi, wmv, asf, flv, mov, mkv, mpeg, mpg, 3gp, wmv, webm, ogm, asx, m2t, m2ts, mts, tif, tiff, wav, mp3, 3ga, m4a, amr, mp2, hwpx, odt, csv";
# 	var exnMnArr = ["jpg","jpeg","gif","png","bmp","txt","pdf","hwp","gul","docx","doc","zip","xls","xlsx","ppt","pptx","mp4","avi","wmv","asf","flv","mov","mkv","mpeg","mpg","3gp","wmv","webm","ogm","asx","m2t","m2ts","mts","tif","tiff","wav","mp3","3ga","m4a","amr","mp2","hwpx","odt","csv"];
# 	var JBOSS_NODE_NAME = 'euser34';
#
#     </script>
# <script src="/resource/js/paid/cmmn/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery-ui.min.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery.cookie.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/bootstrap.min.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/loading.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/sendAjaxReq.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery.form.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/mCustomScrollbar/jquery.mCustomScrollbar.concat.min.js" type="text/javascript">
#     </script>
# <script src="/resource/js/paid/cmmn/pgwslideshow/pgwslideshow.min.js" type="text/javascript">
#     </script>
# <script src="/resource/js/paid/nep/pot/common.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/common.js" type="text/javascript"></script>
#
#     <!-- [if lt IE 9]>
# <script type="text/javascript" src="/resource/js/paid/cmmn/html5shiv.min.js"></script>
# <![endif]-->
#
#     <script src="/resource/js/paid/cmmn/jquery.money.plus.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery.alphanumeric.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/jquery.alerts.js" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/validation.js" type="text/javascript"></script>
# <script src="/resource/js/paid/nep/cmmn/netfunnel/netfunnel.js?ver=1.0" type="text/javascript"></script>
# <script src="/resource/js/paid/nep/cmmn/netfunnel/nfnSkin.js?ver=1.0" type="text/javascript"></script>
# <script src="/resource/js/paid/cmmn/common.popup.js" type="text/javascript"></script>
# <script type="text/javascript">
#                 r\ n\ tvar acesMode = 'frm'; //프레임 접근 구분자
# 	$(function(){
# 		if (acesMode == 'frm') {
# 			$('#contentWrap').addClass('full');  //프레임일 경우 화면 레이아웃 Full
# 		}
#
# 		//$(document).attr('title', $(document).attr('title') + ' | ' + JBOSS_NODE_NAME);
# 	});
#
#     </script>
# </meta>
#     </meta>
# </head>
#
#
# <body>
# <div class="loading black" style="position:fixed; width:100%; height:auto; min-height:100%; z-index:100; top:0; left:0; display:block; opacity:.6;">
# <div style="width:100%; height:100%; top:50%; left:50%; position:absolute;">
#
# <span style="display:table-cell; text-align:center; vertical-align:middle;">
# <img alt="로딩중" src="/resource/images/paid/cmmn/bg_progress.gif" />
# </span>
#
#         </div>
# </div>
# <div id="wrap">
#
#         <!-- 세션에 접근 시스템 구분자가 프레임이 아닐 경우(프레임 통합 메뉴로 접근시 세션에 접근 시스템 구분자를 추가)만 헤더와 푸터를 포함하도록 처리 -->
# <div id="containerAcc"></div>
# <main id="container">
# <section id="member">
# <script type="text/javascript">
#                                         r\ n\ r\ n\ t //20200408/프레임통합 노경용/프레임통합메뉴 관련 변수 추가 시작
# 	var frm_frmMenuMngNo = 'WBF-1202-000044';  //프레임메뉴관리번호
# 	var frm_prcsInstChcePsblYn = 'N';  //처리기관선택가능여부
# 	var frm_thptInfofAgreYn = '';  //제3자정보제공동의추가여부(프레임 관리 옵션)
# 	var frmDsgnType = '';  //프레임 디자인 타입
# 	var frm_frmMenuClsfCd = '';  //메뉴분류코드
# 	var frm_chrgDeptCd = '';  //부서코드
# 	var frm_pttnDrctRcptYn = '';  //민원직접접수여부
# 	var frm_rcptTySctnCd = '';  //접수유형(부서접수/중간분류접수)
# 	var frm_clsfRpsnNm = '';  //신청분야
# 	frm_clsfRpsnNm = frm_clsfRpsnNm.replace("&#x28;", "(").replace("&#x29;", ")");  //신청분야 특수문자 "(", ")" 치환
# 	var frm_frmMngrCnt = '0';  // 메뉴처리 담당자수
# 	var frm_sysCrtnMngrIdCnt = '0';
# 	var frm_clsfAplcYn = 'N';
# 	var thptInfofAgreListYn = '';  //제3자정보제공동의정보 조회 결과 여부
# 	//var frm_lognIndcYn = '';  //로그인표시여부
# 	var requestUri = '/frm/bdgt/bdgtWstRqstInfo.npaid';  //프레임 requestURI
# 	var returnUrl = '';  //returnUrl
# 	var thirdInfoMode = '';  //제3자동의구분
# 	//20200408/프레임통합 노경용/프레임통합메뉴 관련 변수 추가 끝
#
# 	var checkedYn = $('input:checkbox[name="thptInfofAgreYn"]').is(":checked");
# 	var thptInfofAgreYn ="";
# 	var dplcSbrbPrvnStvl = "";
#
# 	$(function(){
# 		returnUrl = fn_getReturnUrl();
# 		if ($.chkEmptyVal(frm_frmMenuMngNo)) {  //세션에 프레임메뉴관리번호가 존재하면 프레임통합메뉴로 인증 후 접근한 것
# 			//$('#subTit').hide();  //헤더 숨김
# 			if(frm_clsfAplcYn == "Y"){
# 				if($.chkEmptyVal(frm_frmMenuClsfCd) && $.chkEmptyVal(frm_clsfRpsnNm)){
# 					$('#div_frmMenuClsfCd').css({
# 						'color':'#000'
# 						,	'paddingTop':'30px'
# 						,	'paddingLeft' : '20px'
# 						,	'fontSize' : '18px'
# 						,	'fontWeight' : 'bold'
# 						,	'marginTop' : '30px'
# 					}).text("신청분야 : " + frm_clsfRpsnNm);
# 					$('#div_frmMenuClsfCd').show();
# 				}
# 			}
#
# 			//프레임 디자인 타입 설정
# 			if ($.chkEmptyVal(frmDsgnType) && frmDsgnType != 'basic') {  //basic=blue
# 				$('#div_frmDsgnType').addClass(frmDsgnType);
# 			}
#
# 			if (frm_prcsInstChcePsblYn != 'Y') {
# 				$('#div_step2').hide();  //2 기관선택 탭 숨김
# 				$('#span_step3').text('2 신청완료');  //탭 숫자 변경
# 			}
#
# 			if (thirdInfoMode == '1' || thirdInfoMode == '5') {  //민원신청(메뉴분류 포함)
# 				if (frm_thptInfofAgreYn == 'Y' && thptInfofAgreListYn == 'Y') {  //제3자정보제공동의
# 					$('#div_thptInfofAgre').show();  //개인정보 제3자 이용동의 영역 보임
#
# // 					if (frm_thptInfofAgreYn == 'Y') {  //개인정보 제3자 이용 동의
# // 						$('#agree_03').prop('checked', true);
# // 					}
# 				}
# 			} else if (thirdInfoMode == '3' || thirdInfoMode == '4') {  //예산낭비신고
# 				$('#div_thptInfofAgre2').show();  //개인정보 제3자 이용동의 영역 보임
# 				if(thirdInfoMode == 3){
# 					$("#p_thptInfofAgreCntnCl").html("예산낭비신고의 이송/이첩, 이관, 업무처리 및 정책 반영을 위해 귀하께서 신고하신 행정기관 외 다른 행정기관에 개인정보가 제공될 수 있습니다.<br><br> 제공되는 개인정보는 신고인 성명, 일반전화, 휴대전화, 전자우편, 주소로 귀하께서 입력하신 정보입니다.<br> 귀하께서는 개인정보 제3자 제공을 동의하지 않을 수 있으며 동의하지 않더라도 신고는 가능합니다.<br> 단, 동의하지 않은 경우 해당기관의 소관업무가 아닌 경우 이송/이첩되지 아니하고 종결처리 될 수 있습니다.");
# 				}else if(thirdInfoMode == 4){
# 					$("#p_thptInfofAgreCntnCl").html("예산절감제안의 이송/이첩, 이관, 업무처리 및 정책 반영을 위해 귀하께서 신고하신 행정기관 외 다른 행정기관에 개인정보가 제공될 수 있습니다.<br><br> 제공되는 개인정보는 신고인 성명, 일반전화, 휴대전화, 전자우편, 주소로 귀하께서 입력하신 정보입니다.<br> 귀하께서는 개인정보 제3자 제공을 동의하지 않을 수 있으며 동의하지 않더라도 신고는 가능합니다.<br> 단, 동의하지 않은 경우 해당기관의 소관업무가 아닌 경우 이송/이첩되지 아니하고 종결처리 될 수 있습니다.");
# 				}
# 			}/*  else if (thirdInfoMode == '4') {  //예산절감제안
# 				$('#div_thptInfofAgre3').show();  //개인정보 제3자 이용동의 영역 보임
# 			} */
#
# 			//if (frm_lognIndcYn != 'Y') {
# 			//$('#div_loginTitle, #div_loginButton').hide();  //로그인 버튼 숨김
# 			//}
#
# 			if ($.chkEmptyVal(dplcSbrbPrvnStvl)) {  //본인 이름 셋
# 				$('#str_authTitle').text('본인 인증되었습니다.');
# 				$('#div_authBox').hide();
# 				$('#div_mbrNm').show();
# 				$('#span_mbrNm').css({'fontSize':'16px', 'fontWeight':'bold'}).val('');
# 				$('#div_btnNext2').show();
# 			}
# 		}
#
# 		//저장 버튼 클릭 이벤트
# 		//$('#btnOpen').on('click', function(){
# 		//alert('[공지] 본인 인증 모듈 테스트 중이라 불안정할 수 있으니 양해 부탁드립니다.');
# 		//return;
# 		//});
#
# 		//sameSite 오류 시 팝업창 호출 20201020-노경용
# 		var urlChk=false;
# 		var agent = navigator.platform.toLowerCase();
# 		if((navigator.appName == 'Netscape' && navigator.userAgent.search('Trident') != -1) || (agent.indexOf('msie') != -1)){
# 			$('#alert_wrap').hide();
# 		}else{
# 			if(opener){
# 				$('#alert_wrap').hide();
# 			}else{
# 				$('#alert_wrap').show();
# 				switch ($('#frm_frmUrlSn').val()) {
# 					case "1"  : $('#smesite_pop').html('<span>민원분류</span>'); break;
# 					case "2"  : $('#smesite_pop').html('<span>민원신청</span>'); break;
# 					case "3"  : $('#smesite_pop').html('<span>공개민원</span>'); break;
# 					case "4"  : $('#smesite_pop').html('<span>나의민원</span>'); break;
# 					case "5"  : $('#smesite_pop').html('<span>민원FAQ</span>'); break;
# 					case "6"  : $('#smesite_pop').html('<span>일반제안</span>'); break;
# 					case "7"  : $('#smesite_pop').html('<span>공개제안</span>'); break;
# 					case "8"  : $('#smesite_pop').html('<span>나의제안</span>'); break;
# 					case "10" : $('#smesite_pop').html('<span>우수제안</span>'); break;
# 					case "11" : $('#smesite_pop').html('<span>대화형목록</span>'); break;
# 					case "12" : $('#smesite_pop').html('<span>온라인공청회</span>'); break;
# 					case "13" : $('#smesite_pop').html('<span>설문형목록</span>'); break;
# 					case "14" : $('#smesite_pop').html('<span>입법예고</span>'); break;
# 					case "15" : $('#smesite_pop').html('<span>행정예고</span>'); break;
# 					case "16" : $('#smesite_pop').html('<span>입법·행정예고</span>'); break;
# 					case "17" : $('#smesite_pop').html('<span>공모제안</span>');  break;
# 					case "18" : $('#smesite_pop').html('<span>민원·정책Q&A</span>'); break;
# 					case "24" : $('#smesite_pop').html('<span>외국어민원신청</span>'); break;
# 					case "25" : $('#smesite_pop').html('<span>나의외국어민원</span>'); break;
# 					case "21" : $('#smesite_pop').html('<span>예산낭비신고</span>'); break;
# 					case "22" : $('#smesite_pop').html('<span>나의신고</span>'); break;
# 					case "23" : $('#smesite_pop').html('<span>예산절감제안</span>'); break;
# 					case "19" : $('#smesite_pop').html('<span>민원Q&A</span>'); break;
# 					case "20" : $('#smesite_pop').html('<span>정책Q&A</span>'); break;
# 					case "32" : $('#smesite_pop').html('<span>온라인상담신청</span>'); break;
# 					case "33" : $('#smesite_pop').html('<span>온라인상담목록</span>'); break;
# 					default: urlChk=true; break;
# 				}
# 			}
# 		}
# 		var returnUrlval = "";
# 		if(urlChk){
# 			returnUrlval = 'https://www.epeople.go.kr'+returnUrl;
# 		}else{
# 			if($('#frm_frmAllUrl').val()==""){
# 				returnUrlval = 'https://www.epeople.go.kr';
# 			}else{
# 				returnUrlval = $('#frm_frmAllUrl').val();
# 			}
# 		}
# 		$('#smesite_pop').on('click', function(){
# 			var size = "width='800',height='800',scrollbars=1";
# 			window.open( returnUrlval , "_blank", size);
# 		});
#
# 		$('#agree_01').focus();
# 	});  //end ready
#
#
# 	//제3자 동의 체크
# 	function fn_chkAgree() {
# 		return true;
#
# 		//선택항목 동의 체크
# 		/* if (!$('#agree_02').prop('checked')) {
# 			jAlert('선택항목 수집 및 이용 동의에 체크하셔야 합니다.');
# 			$('#agree_02').focus();
# 			return false;
# 		} else {
# 			$('#indvifChceItmAgreYn').val('Y');
# 			return true;
# 		} */
#
# 		//선택사항 체크
# 		/* if (!$('#agree_03').prop('checked')) {
# 			jAlert('개인정보 제3자 이용 동의 방침에 동의하셔야 합니다.');
# 			$('#agree_03').focus();
# 			return false;
# 		} else {
# 			$('#thptInfofAgreYn').val('Y');
# 			return true;
# 		} */
#
# 		//var url = '/frm/pttn/pttnRqstInfo.paid?frmMenuMngNo=' + frm_frmMenuMngNo;  //민원 신청 기본 페이지
# 		//$(location).attr('href', url);
# 		//$('#agreeFrm').attr({'action' : url, 'method' : 'get'}).submit();
# 	}
#
# 	//간편인증 로그인
# 	function fn_prcsLoginSimple() {
# 		if (fn_chkAgree()) {
# 			var param = {"returnUrl" : returnUrl, "callBackFncNm" : "fn_nmbrLognPrcs"};
# 			//v1.0
# 			//gfn_openPopupPost("simpleCrtfPopup", param, "simpleCrtfPopup", "/nep/crtf/simpleCrtfPopup.npaid", 661, 666);
# 			//v1.5
# 			//gfn_openPopupPost("simpleCrtfPopup", param, "simpleCrtfPopup", "/nep/crtf/simpleCrtfPopup15.npaid", 661, 662);
# 			//v1.51
# 			gfn_openPopupPost("simpleCrtfPopup", param, "simpleCrtfPopup", "/nep/crtf/simpleCrtfPopup15.npaid", 838, 640);
# 		}
# 	}
#
# 	//모바일신분증 로그인
# 	function fn_prcsLoginMobile() {
# 		if (fn_chkAgree()) {
# 			var param = {"returnUrl" : returnUrl, "callBackFncNm" : "fn_nmbrLognPrcs", "mobileYn": "false"};
# 			gfn_openPopupPost("mobileCrtfPopup", param, "mobileCrtfPopup", "/nep/crtf/mobilCrtPopup.npaid", 838, 615);
# 		}
# 	}
#
# 	//아이핀
# 	function fn_ipinModulCheck() {
# 		if (fn_chkAgree()) {
# 			var param = {"returnUrl" : returnUrl, "callBackFncNm" : "fn_nmbrLognPrcs"};
# 			gfn_openPopupPost("ipinCrtfPopup", param, "ipinCrtfPopup", "/nep/crtf/ipinCrtfPopup.npaid", 480, 520);
# 		}
# 	}
#
# 	//공동인증서(구 공인인증서)
# 	function fn_ogcrCheck() {
# 		// 실명인증시스템(행정안전부) 작업
# 		var startDay  = new Date(2020, 09, 10);	// 08->09월이 됨. 2020.10.10일
# 		var startTime = new Date(startDay.getTime() );// 60000(1초)
# 		var endDay  = new Date(2020, 09, 10);
# 		var endTime = new Date(endDay.getTime()	+ 20*60*60000 );// 20시
# 		var now = new Date();
# 		//alert("startTime: "+startTime +",endTime: "+endTime);
# 		var aMessage ="실명인증시스템(행정안전부) 점검으로인해 한시적으로 공동인증서(구 공인인증서) 이용이 중단됩니다.<br/><br/>중단시간: 2020.10.10.(토) 00:00 ~ 20:00";
#
# 		if(startTime <= now && now < endTime) {
# 			jAlert(aMessage);
# 			return;
# 		}
#
# 		if (fn_chkAgree()) {
# 			var param = {"callId" : "LOGIN_CHECK", "returnUrl" : returnUrl, "callBackFncNm" : "fn_nmbrLognPrcs"};
# 			//gfn_openPopupPost("orctInfoCrtfPopup", param, "orctInfoCrtfPopup", "/nep/crtf/orctInfoCrtfPopup.npaid", 480, 600);
# 			gfn_openPopupPost("orctInfoCrtfPopupRenew", param, "orctInfoCrtfPopupRenew", "/nep/crtf/orctInfoCrtfPopupRenew.npaid", 480, 600);
# 		}
# 	}
#
# 	//금융인증서
# 	function fn_ficrCheck() {
# 		// 실명인증시스템(행정안전부) 작업
# 		var startDay  = new Date(2020, 09, 10);	// 08->09월이 됨. 2020.10.10일
# 		var startTime = new Date(startDay.getTime() );// 60000(1초)
# 		var endDay  = new Date(2020, 09, 10);
# 		var endTime = new Date(endDay.getTime()	+ 20*60*60000 );// 20시
# 		var now = new Date();
# 		//alert("startTime: "+startTime +",endTime: "+endTime);
# 		var aMessage ="실명인증시스템(행정안전부) 점검으로인해 한시적으로 금융인증서 이용이 중단됩니다.<br/><br/>중단시간: 2020.10.10.(토) 00:00 ~ 20:00";
#
# 		if(startTime <= now && now < endTime) {
# 			jAlert(aMessage);
# 			return;
# 		}
#
# 		if (fn_chkAgree()) {
# 			var param = {"callId" : "LOGIN_CHECK", "returnUrl" : returnUrl, "callBackFncNm" : "fn_nmbrLognPrcs"};
# 			gfn_openPopupPost("fictInfoCrtfPopup", param, "fictInfoCrtfPopup", "/nep/crtf/fictInfoCrtfPopup.npaid", 480, 600);
# 		}
# 	}
#
# 	//휴대전화
# 	function fn_phoneCrtfcCheck() {
# 		if (fn_chkAgree()) {
# 			var param = {"returnUrl" : returnUrl, "callBackFncNm" : "fn_nmbrLognPrcs"};
# 			gfn_openPopupPost("cpCrtfPopup", param, "cpCrtfPopup", "/nep/crtf/cpCrtfPopup.npaid", 500, 600);
# 		}
# 	}
#
# 	//외국인등록번호
# 	function fn_undrtkrNoCheck() {
# 		if (fn_chkAgree()) {
# 			var param = {"returnUrl" : returnUrl, "callBackFncNm" : "fn_nmbrLognPrcs"};
# 			gfn_openPopupPost("inhbFgnoInfoCrtfPopup", param, "inhbFgnoInfoCrtfPopup", "/nep/crtf/inhbFgnoInfoCrtfPopup.npaid", 550, 450);
# 		}
# 	}
#
# 	//로그인 성공시 페이지 이동
# 	function fn_nmbrLognPrcs(param) {
# 		$('#loginMode').val('frm');
# 		$('#returnUrl').val(returnUrl);
# 		if($('#agree_03').prop('checked')){
# 			$('#thptInfofAgreYn').val("Y");
# 			$('#frm_thptInfofAgreYn').val("Y");
# 		}
# 		if($('#agree_05').prop('checked')){
# 			$('#thptInfofAgreYn').val("N");
# 			$('#frm_thptInfofAgreYn').val("Y");
# 		}
# 		/* 프레임 관련 변수 추가 하여 submit 20200413 노경용 */
# 		var action = $.trim(param.returnUrl);
# 		var form = $("form#frmMngInfoVO");
# 		form.attr("action", action).submit();
# 	}
#
# 	//로그인 페이지로 이동
# 	function fn_moveLogin() {
# 		if (fn_chkAgree()) {
# 			var url = '/frmSub/crtf/frmUserLogn.npaid?loginMode=frm&returnUrl=' + returnUrl;
# 			$('#loginMode').val('frm');
# 			$('#returnUrl').val(returnUrl);
# 			$('#agreeFrm').attr({'action' : url, 'method' : 'get'}).submit();
# 		}
# 	}
#
# 	//get returnUrl
# 	function fn_getReturnUrl() {
# 		var returnUrl = '';
#
# 		if ($.chkEmptyVal(requestUri)) {
# 			if (requestUri.indexOf('pttnRqstInfo.') > -1) {  //민원신청
# 				thirdInfoMode = '1';
# 				returnUrl = "/frmSub/pttn/gnrlPttn/FrmPttnRqstWrtnInfo.paid";
# 			} else if (requestUri.indexOf('gnrlPrplRqstInfo.') > -1) {  //일반제안
# 				thirdInfoMode = '2';
# 				returnUrl = "/frmSub/prpl/selectGnrlPrpslRqstPage.paid";
# 			} else if (requestUri.indexOf('bdgtWstRqstInfo.') > -1) {  //예산낭비신고
# 				thirdInfoMode = '3';
# 				returnUrl = "/frmSub/bdgtWst/selectBdgtWstRqstPage.paid";
# 			} else if (requestUri.indexOf('bdgtRdcnPrplInfo.') > -1) {  //예산절감제안
# 				thirdInfoMode = '4';
# 				returnUrl = "/frmSub/bdgtWst/selectBdgtRdcnPrpslRqstPage.paid";
# 			} else if (requestUri.indexOf('frmPttnClsfList.') > -1) {  //메뉴분류에서 민원신청으로 넘어온 경우
# 				thirdInfoMode = '5';
# 				returnUrl = "/frmSub/pttn/gnrlPttn/FrmPttnRqstWrtnInfo.paid";
# 			} else if(requestUri.indexOf('ppaRqst.') > -1){	//적극행정
# 				thirdInfoMode = '5';
# 				returnUrl = "/frmSub/ppa/frmPpaRqstWrtnInfo.paid";
# 			} else if(requestUri.indexOf('psaStmt.') > -1){ //소극신고
# 				thirdInfoMode = '5';
# 				returnUrl = "/frmSub/psa/frmPsaStmtWrtnCont.paid";
# 			} else if(requestUri.indexOf('psaResttemnt.') > -1){ //소극재신고
# 				thirdInfoMode = '5';
# 				returnUrl = "/frmSub/psa/frmPsaResttemnt.paid";
# 			}
#
# 			else {  //frmUserLogn.npaid (나의민원같이 .paid여서 로그인 페이지로 넘어온 경우)
# 				thirdInfoMode = '0';
# 				returnUrl = '';
# 			}
# 		}
# 		//return encodeURIComponent(returnUrl);
# 		return returnUrl;
# 	}
#
# 	//다음 버튼 클릭 이벤트
# 	function fn_moveNext() {
#
# 		if(returnUrl != "/frmSub/bdgtWst/selectBdgtWstRqstPage.paid" && returnUrl != "/frmSub/bdgtWst/selectBdgtRdcnPrpslRqstPage.paid"){
# 			if($('#agree_03').prop('checked')){
# 				$('#thptInfofAgreYn').val("Y");
# 				$('#frm_thptInfofAgreYn').val("Y");
# 			}
# 			if($('#agree_05').prop('checked')){
# 				$('#thptInfofAgreYn').val("N");
# 				$('#frm_thptInfofAgreYn').val("Y");
# 			}
# 		}else{
# 			if($('#agree_04').prop('checked')){
# 				$('#thptInfofAgreYn').val("Y");
# 				$('#frm_thptInfofAgreYn').val("Y");
# 			}
# 		}
#
# 		if ($.chkEmptyVal($('#span_mbrNm').val())) {
# 			//로딩바 추가 20200623-노경용
# 			$('.loading_submit').show();
# 			/* 프레임 관련 변수 추가 하여 submit 20200413 노경용 */
# 			var action = $.trim(returnUrl);
# 			var form = $("form#frmMngInfoVO");
# 			form.attr("action", action).submit();
# 		} else {
# 			jAlert('본인 인증이 필요합니다.');
# 			return;
# 		}
# 	}
#
# 	// SNS 간편 로그인
# 	function fn_snsLogin(socialType) {
# // 		gfn_openPopupPost("snsViewer", '' ,"snsViewer", "about:blank", 600, 550);
# 		$('#snsFrm input[name=socialType]').val(socialType);
# 		$('#snsFrm input[name=returnUrl]').val(socialType);
# 		$('#snsFrm input[name=checkType]').val('add');
# // 		$("#snsFrm").attr("target", "snsViewer");
# 		$('#snsFrm').attr('action', '/nep/crtf/selectSocialLogn.npaid');
# 		$('#snsFrm').submit();
# 	}
#
#
#                 </script>
# <form id="agreeFrm" name="agreeFrm">
#
#                     <!-- <input type="hidden" id="indvifSntlItmAgreYn" name="indvifSntlItmAgreYn" value="N" />
# 	<input type="hidden" id="thptInfofAgreYn" name="thptInfofAgreYn" value="N" /> -->
# <input name="_csrf" type="hidden" value="d4e8959f-0d9b-48f1-89d0-8559aafaae91" />
# <input id="loginMode" name="loginMode" type="hidden" value="" />
# <input id="returnUrl" name="returnUrl" type="hidden" value="" />
#
#                 </form>
# <header id="subTit" style="display:none;">
# <h3>개인 정보 수집 및 이용 안내</h3>
# </header>
# <article id="txt">
# <form action="" id="frmMngInfoVO" method="post" name="frmMngInfoVO">
#
#                         <!-- 20200408/프레임통합 노경용/프레임통합메뉴 관련 변수 -->
# <input id="frm_frmMenuMngNo" name="frm_frmMenuMngNo" type="hidden" value="WBF-1202-000044" />
# <input id="frm_instCd" name="frm_instCd" type="hidden" value="3060000" />
# <input id="frm_clsfAplcYn" name="frm_clsfAplcYn" type="hidden" value="N" />
# <input id="frm_rcptPathInstCd" name="frm_rcptPathInstCd" type="hidden" value="3060000" />
# <input id="frm_frmUrlSn" name="frm_frmUrlSn" type="hidden" value="21" />
# <input id="frm_frmAllUrl" name="frm_frmAllUrl" type="hidden" value="https://www.epeople.go.kr/frm/bdgt/bdgtWstRqstInfo.npaid?frmMenuMngNo=WBF-1202-000044" />
# <input id="frm_prcsInstChcePsblYn" name="frm_prcsInstChcePsblYn" type="hidden" value="N" />
# <input id="frm_thptInfofAgreYn" name="frm_thptInfofAgreYn" type="hidden" value="" />
# <input id="frmDsgnType" name="frmDsgnType" type="hidden" value="" />
# <input id="frm_frmMenuClsfCd" name="frm_frmMenuClsfCd" type="hidden" value="" />
# <input id="frm_chrgDeptCd" name="frm_chrgDeptCd" type="hidden" value="" />
# <input id="frm_pttnDrctRcptYn" name="frm_pttnDrctRcptYn" type="hidden" value="" />
# <input id="frm_rcptTySctnCd" name="frm_rcptTySctnCd" type="hidden" value="" />
# <input id="frm_clsfRpsnNm" name="frm_clsfRpsnNm" type="hidden" value="" />
# <input id="frm_frmMngrCnt" name="frm_frmMngrCnt" type="hidden" value="0" />
# <input id="frm_sysCrtnMngrIdCnt" name="frm_sysCrtnMngrIdCnt" type="hidden" value="0" />
# <input id="frm_areaSntlYn" name="frm_areaSntlYn" type="hidden" value="" />
# <input id="frm_atchFileSntlYn" name="frm_atchFileSntlYn" type="hidden" value="" />
# <input id="frm_drqstrInfoIndcYn" name="frm_drqstrInfoIndcYn" type="hidden" value="" />
# <input id="frm_dpttnrInfoSntlYn" name="frm_dpttnrInfoSntlYn" type="hidden" value="" />
# <input id="frm_pttnSctnCd" name="frm_pttnSctnCd" type="hidden" value="80030001" />
# <input id="frm_scryPttnSctnCd" name="frm_scryPttnSctnCd" type="hidden" value="0A070002" />
# <input id="frm_gdncWrdsUseYn" name="frm_gdncWrdsUseYn" type="hidden" value="" />
# <input id="frm_egppYn" name="frm_egppYn" type="hidden" value="N" />
# <input id="frm_cnrsYn" name="frm_cnrsYn" type="hidden" value="Y" />
# <input id="frm_addnCltnItmUseYn" name="frm_addnCltnItmUseYn" type="hidden" value="" />
# <input id="frm_pttnClsfCd" name="frm_pttnClsfCd" type="hidden" value="" />
# <input id="frm_prcsTmltNumd" name="frm_prcsTmltNumd" type="hidden" value="" />
# <input id="frm_basePrcsPrd" name="frm_basePrcsPrd" type="hidden" value="7" />
# <input id="frm_menuCd" name="frm_menuCd" type="hidden" value="BW001" />
# <input id="frm_proPotMngrIdCnt" name="frm_proPotMngrIdCnt" type="hidden" value="0" />
# <input id="frm_ablYn" name="frm_ablYn" type="hidden" value="N" />
# <input id="acesMode" name="acesMode" type="hidden" value="frm" />
# <input id="frm_lwsInstNm" name="frm_lwsInstNm" type="hidden" value="중랑구" />
# <input id="frm_cntnCl" name="frm_cntnCl" type="hidden" value="" />
# <input id="frm_oppbYn" name="frm_oppbYn" type="hidden" value="" />
# <input id="frm_pttnKndCd" name="frm_pttnKndCd" type="hidden" value="90100010" />
# <input id="thptInfofAgreYn" name="thptInfofAgreYn" type="hidden" value="">
# </input>
#                     </form>
# <div class="cl_type" id="div_frmDsgnType">
#                         <!-- 프레임 디자인 타입 설정 -->
# <div class="default_order">
# <div class="order_item icon_1 on">
#
# <span title="현재 신청서 작성 단계">1 신청서 작성</span>
# </div>
# <div class="order_item icon_2" id="div_step2">
# <span title="기관선택 단계">2 기관선택</span>
# </div>
# <div class="order_item icon_3">
# <span id="span_step3" title="신청완료 단계">3 신청완료</span>
#
#                             </div>
# </div>
# <div id="div_frmMenuClsfCd" style="display:none;"></div>
#
#                         <!--
# 		<div id="alert_wrap" style="display:none;">
# 		    <div class="popup_wrap_blank">
# 		        <div class="pl_20">
# 		            <p><h5><span class="orange">※ 일부 브라우저에서는 제조사의 강화된 보안정책으로 인해, 정상적인 이용에 제한이 있을 수 있습니다.</span></h5></p>
# 		            <p><h5><span class="orange"> <button type="button" class="bbs_btn fill" id="smesite_pop"><span>나의신문고</span></button>&nbsp;&nbsp;버튼을 누르시거나, 국민신문고(www.epeople.go.kr)사이트를 이용하시기 바랍니다.</span></h5></p>
# 		        </div>
# 		    </div>
# 		</div>
# 		 -->
#
#                         <div class="login_box mb_50 mt_0">
#
#                             <!-- 			<div class="tit_box">
#                             <strong>본인 인증</strong>
#                         </div>
#                         <div class="form_box">
#                             <div class="be_join">
#                                 <a href="javascript:void(0);" class="be_01" onclick="fn_ipinModulCheck();"><span>아이핀</span></a>
#                                 <a href="javascript:void(0);" class="be_02" onclick="fn_ogcrCheck();"><span>공동인증서(구 공인인증서)</span></a>
#                                 <a href="javascript:void(0);" class="be_03" onclick="fn_phoneCrtfcCheck();"><span>휴대전화</span></a>
#                                 <a href="javascript:void(0);" class="be_04" onclick="fn_undrtkrNoCheck();"><span>외국인등록번호</span></a>
#                             </div>
#                         </div> -->
#
#                             <div class="titBox slideTit">
# <strong id="str_authTitle">본인 인증(비회원 로그인)</strong>
#
#                             </div>
# <div class="slideBox">
# <a class="slideBtn on" href="javaScript:void(0);" id="btnOpen">열기</a>
# <div class="form_box">
# <div class="bSch_row" id="div_mbrNm" style="display:none;">
# <div class="bSch_col">
#
# <strong>신청인 이름 : </strong><input disabled="disabled" id="span_mbrNm" title="신청인 이름" type="text" value="" />
# <span id="div_btnNext2" style="display:none;float:right">
# <button class="btn fill" id="btnNext" onclick="fn_moveNext();" type="button"><span>다음</span></button>
# </span>
#
#                                         </div>
# </div>
# <div class="be_join" id="div_authBox">
# <a class="be_00" href="javascript:void(0);" onclick="fn_prcsLoginSimple()" title="간편인증 새창"><span>간편인증</span></a>
# <a class="be_06" href="javascript:void(0);" onclick="fn_prcsLoginMobile()" title="모바일신분증 새창"><span>모바일신분증</span></a>
# <a class="be_01" href="javascript:void(0);" onclick="fn_ipinModulCheck();" title="아이핀 인증 새창 열림"><span>아이핀</span></a>
# <a class="be_05" href="javascript:void(0);" onclick="fn_ficrCheck();" title="금융인증서 인증 새창 열림"><span>금융인증서</span></a>
# <a class="be_02" href="javascript:void(0);" onclick="fn_ogcrCheck();" title="공동인증서(구 공인인증서) 인증 새창 열림"><span>공동인증서(구 공인인증서)</span></a>
# <a class="be_03" href="javascript:void(0);" onclick="fn_phoneCrtfcCheck();" title="휴대전화 인증 새창 열림"><span>휴대전화</span></a>
#
#                                         <!-- <a href="javascript:void(0);" class="be_04" onclick="fn_undrtkrNoCheck();" title="외국인등록번호 인증 새창 열림" ><span>외국인등록번호</span></a> -->
#
#                                     </div>
# </div>
# </div>
#
#                             <!-- SNS 간편 로그인 시작 -->
#
#                             <!-- SNS 간편 로그인 끝 -->
# <div class="titBox slideTit" id="div_loginTitle" style="display:none;">
# <strong>국민신문고 로그인</strong>
# </div>
# <div class="btnArea center" id="div_loginButton" style="display:none;">
#
# <button class="btn gray" id="btnLogin" onclick="fn_moveLogin();" type="button"><span>로그인</span></button><br /><br />
# <span id="str_welcome">※ 로그인을 하시면 더 많은 정보를 편리하게 이용하실 수 있습니다.</span>
#
#                             </div>
#
#                         </div>
# <div class="btnArea right" id="div_btnNext" style="display:none;">
#
# <button class="btn fill" id="btnNext" onclick="fn_moveNext();" type="button"><span>다음</span></button>
#
#                         </div>
#
#                     </div>
#
#                     <!-- 로딩 화면 추가 20200618-노경용 -->
# <div class="loading_submit" style="display:none;">
# <div class="apload_ing"></div>
# <div class="load_box">
#
# <span><img alt="불러오는 중" src="/resource/images/paid/biz/content/load_ing.png" /></span>
# <strong>화면을 불러오는 중</strong>
#
#                             <p>요청하신 화면을 불러오는 중입니다. 잠시만 기다려주십시오.</p>
# </div>
# </div>
#
#                 </article>
# </section>
# </main>
#
#     </div>
#
#     <!-- 1 : 개인정보 스크립트 -->
# <script src="/resource/app/applex_wdigm_html5/applex_local.js?version=1.08" type="text/javascript"></script>
#
#     <!-- 2 : 첨부파일 변환 스크립트 -->
# <iframe class="uploadIFrame1" id="uploadIFrame1" name="uploadIFrame1" style="display: none; visibility: hidden;" title="첨부파일 변환"></iframe>
#
#     <!-- 3 : 개인정보 차단 스크립트 -->
#
#     <!-- 4 : onchang 함수 -->
#
#     <!-- 5 : 첨부파일 변환 알림 문구 -->
#
#     <!-- <div id="applex_wdigm_html5_waiting"></div> -->
#
#     <!-- 2025-09-04 15:55:22 -->
#
#     <!-- euser34 -->
#
# </body>
#
#
# </html>
